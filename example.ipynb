# %% [markdown]
# ## Load the dataset

# %%
import json
data = json.load(open('data.json'))

# %% [markdown]
# ## Analyze the dataset

# %%
## Print the first 10 objects
for i in range(10):
    print(data[i])
# Out:
# {'page_content': '\n\n\n\n\n \n\n\n\n\n\n\nContact Us :: Giving to USF\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nUniversity of South Florida\n\n\n\n\n\n\xa0(813) 974-2035\n                            \xa0|\xa0\n                        \n\n\xa0Contact Us\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                Give Now\n                            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                Impact                            \n\n\n\n                                Where to Give\n                            \n\n\n\n                                How to Give to USF\n                            \n\n\n\n                                Get Involved\n                            \n\n\n\n                                About Us\n                            \n\n\n\n Search the Site\n                            \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                               
# ...

# %%
## Print the structure of an object (every objects in the dataset have the same structure)
## Choose an object you want to print
object_number = 1246
print(f"All the keys of the object number {object_number} are: ", list(data[object_number].keys()))
for key, value in data[object_number].items():
    print(key, ':', value)
# Out:
# All the keys of the object number 1246 are:  ['page_content', 'metadata']
# page_content : Description: University of South Florida Libraries | 259 followers on LinkedIn. We&#39;ve Got a Book For That! | The University of South Florida Libraries accelerate learning and knowledge production through distinctive collections, information service innovation, and thought leadership.  #GoBullsPage Content:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# University of South Florida Libraries | LinkedIn
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Skip to main content
#
#
#
#
# LinkedIn
#
#
#
#
#
#
#
#
#
#         Articles
#
#
#
#
#
#
#
#
#         People
#
#
#
#
#
#
#
#
#         Learning
#
#
#
#
#
#
#
#
#         Jobs
#
#
#
#
#
#
#       Join now
#
#
#           Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     University of South Florida Libraries
#
#
#
#                     Higher Education
#
#
#
#         Tampa, Florida  259 followers
#
#
#
# ...
